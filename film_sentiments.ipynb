# %%
import os
import pandas as pd

# %%
import os
import pandas as pd

# Load the dataset
def load_data(directory):
    data = {'review': [], 'sentiment': []}
    for sentiment in ['pos', 'neg']:
        path = os.path.join(directory, sentiment)
        for file in os.listdir(path):
            with open(os.path.join(path, file), 'r', encoding='utf-8') as f:
                data['review'].append(f.read())
                data['sentiment'].append(1 if sentiment == 'pos' else 0)
    return pd.DataFrame(data)

train_data = load_data("train")

# %%
train_data.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     25000 non-null  object
#  1   sentiment  25000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 390.8+ KB

# %%
# i. Convert feature variable to lower case

train_data['text'] = train_data['review'].str.lower()

# %%
# ii. Tokenization

from nltk.tokenize import word_tokenize
train_data['text'] = train_data['text'].apply(word_tokenize)

# %%
# iii. Punctuation removal

import string

def remove_punctuation(token):
    return [i for i in token if i not in string.punctuation]
train_data['text'] = train_data['text'].apply(remove_punctuation)

# %%
"""
text = "I love %^Python & in a way, but. / is not ? rewmet @# all in all  !"

clean = text.translate(str.maketrans('','',string.punctuation))
print(clean)

the first str ('') specifies characters that need to be replaced
the second str ('') specifies characters with which they are to be replaced
the third str (string.punctuation) specifies xters that are to be deleted

"""
# Out:
# '\ntext = "I love %^Python & in a way, but. / is not ? rewmet @# all in all  !"\n\nclean = text.translate(str.maketrans(\'\',\'\',string.punctuation))\nprint(clean)\n\nthe first str (\'\') specifies characters that need to be replaced\nthe second str (\'\') specifies characters with which they are to be replaced\nthe third str (string.punctuation) specifies xters that are to be deleted\n\n'

# %%
# v. Remove stopwords

from nltk.corpus import stopwords
remove_stopwords = stopwords.words('english')

def remove_words(tokens):
    return [i for i in tokens if i not in remove_stopwords]
train_data['text'] = train_data['text'].apply(remove_words)

# %%
# iv. Lemmatization   - I opted for Lemmatization in place of Stemming

from nltk.stem import WordNetLemmatizer
lemma = WordNetLemmatizer()

def lemmatize_data(token):
    return [lemma.lemmatize(i) for i in token]
train_data['text'] = train_data['text'].apply(lemmatize_data)

# %%
# vi. Feature Extraction

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
vectorizer = CountVectorizer()
train_data['text'] = train_data['text'].apply(lambda x: ' '.join(x))
X = vectorizer.fit_transform(train_data['text'])

print(vectorizer.vocabulary_)
# Out:
# {'bromwell': 8665, 'high': 28641, 'cartoon': 10109, 'comedy': 12543, 'ran': 49511, 'time': 61886, 'program': 48148, 'school': 53763, 'life': 35919, 'teacher': 60807, '35': 640, 'year': 68629, 'teaching': 60808, 'profession': 48104, 'lead': 35359, 'believe': 6325, 'satire': 53354, 'much': 41095, 'closer': 12027, 'reality': 49879, 'scramble': 53934, 'survive': 59830, 'financially': 22834, 'insightful': 31335, 'student': 58977, 'see': 54264, 'right': 51715, 'pathetic': 45236, 'pomp': 47089, '
 2150, 'fight': 22694, 'flight': 23221, 'kill': 33925, 'killed': 33930, 'love': 36737, 'connection': 13191, 'necessary': 41969, 'plot': 46798, 'found': 23820, 'stink': 58513, 'observant': 43208, 'film': 22749, 'prior': 47961, 'show': 55461, 'tender': 61053, 'side': 55663, 'compared': 12717, 'slapstick': 56254, 'blazing': 7250, 'saddle': 52864, 'young': 68806, 'frankenstein': 23959, 'spaceballs': 57316, 'something': 57052, 'valuable': 65453, 'hand': 27471, 'stupid': 59036, 'know': 34258, 'money': 40486, 'maybe': 38563, 'give': 25587, 'instead': 31399, 'using': 65261, 'monopoly': 40537, 'inspire': 31378, 'others': 44051, 'brilliant': 8540, 'over': 44240, 'acting': 1576, 'best': 6637, 'dramatic': 18504, 'hobo': 28936, 'lady': 34791, 'ever': 21085, 'seen': 54290, 'scene': 53618, 'clothes': 12040, 'warehouse': 66744, 'second': 54202, 'none': 42660, 'corn': 13762, 'face': 21772, 'good': 26004, 'anything': 3536, 'take': 60419, 'lawyer': 35306, 'also': 2692, 'superb': 59569, 'accused': 1468, 'turncoat': 63421, 'selling': 54391, 'bos': 8020, 'dishonest': 17472, 'shrug': 55540, 'indifferen ...

# %%
# i. Split dataset into train and test sets

from sklearn.model_selection import train_test_split
y = train_data.sentiment
x_train, x_val, y_train, y_val = train_test_split(X, y, train_size = 0.9, random_state = 42)

# %%
# ii. Apply Naive Bayes Algorithm

from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix, classification_report

model = MultinomialNB()
model.fit(x_train, y_train)
# Out:
# MultinomialNB()

# %%
test_data = load_data("test")

# %%
test_data['sentiment'].value_counts()
# Out:
# sentiment
# 1    12500
# 0    12500
# Name: count, dtype: int64

# %%
test_data.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
test_data['test'] = test_data['review'].str.lower()

test_data['test'] = test_data['test'].apply(word_tokenize)

# %%
test_data['test'] = test_data['test'].apply(remove_punctuation)

# %%
test_data['test'] = test_data['test'].apply(remove_words)

# %%
test_data['test'] = test_data['test'].apply(lemmatize_data)

# %%
test_data['test'] = test_data['test'].apply(lambda x: ' '.join(x))
x_test = vectorizer.fit_transform(test_data['test'])
y_test = test_data.sentiment

# %%
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 y_pred = model.predict(x_test)
#       2 print(classification_report(y_test, y_pred))
#
# File ~\anaconda3\Lib\site-packages\sklearn\naive_bayes.py:101, in _BaseNB.predict(self, X)
#      87 """
#      88 Perform classification on an array of test vectors X.
#      89
#    (...)
#      98     Predicted target values for X.
#      99 """
#     100 check_is_fitted(self)
# --> 101 X = self._check_X(X)
#     102 jll = self._joint_log_likelihood(X)
#     103 return self.classes_[np.argmax(jll, axis=1)]
#
# File ~\anaconda3\Lib\site-packages\sklearn\naive_bayes.py:574, in _BaseDiscreteNB._check_X(self, X)
#     572 def _check_X(self, X):
#     573     """Validate X, used only in predict* methods."""
# --> 574     return self._validate_data(X, accept_sparse="csr", reset=False)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:625, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     622     out = X, y
#     624 if not no_val_X and check_params.get("ensure_2d", True):
# --> 625     self._check_n_features(X, reset=reset)
#     627 return out
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:414, in BaseEstimator._check_n_features(self, X, reset)
#     411     return
#     413 if n_features != self.n_features_in_:
# --> 414     raise ValueError(
#     415         f"X has {n_features} features, but {self.__class__.__name__} "
#     416         f"is expecting {self.n_features_in_} features as input."
#     417     )
#
# ValueError: X has 68253 features, but MultinomialNB is expecting 69303 features as input.
